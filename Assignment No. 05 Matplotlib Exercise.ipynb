# %% [markdown]
# #### Assignment No.05 Matplotlib Exercises

# %% [markdown]
# #### Follow the instructions to recreate the plots using this data:

# %%
import numpy as np
x=np.arange(0,100)
y=x*2
z=x**3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### ** Follow along with these steps: **
#
# ** Create a figure object called fig using plt.figure() **
# ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig=plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# #### ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# #### Now plot (x,y) on both axes. And call your figure object to show it.

# %%
ax1.plot(x,y)
ax2.plot(x,y)
fig

# %% [markdown]
# #### Now plot (x,y) on both axes. And call your figure object to show it.

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# #### Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:

# %%
ax1.plot(x,z)
ax1.set_xlabel('x')
ax1.set_ylabel('z')
ax2.plot(x,y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
fig1

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot below.

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# #### Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style

# %%
axes[0].plot(x,y,linestyle='--',color='orange')
axes[1].plot(x,z,linestyle='-',color='black')
fig

# %% [markdown]
# #### See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(15,2))

axes[0].plot(x,y,color="black", lw=7)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x,z,color="yellow", lw=5, ls='--')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
fig
